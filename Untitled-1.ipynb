# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import warnings
warnings.filterwarnings('ignore')
from sklearn.impute import KNNImputer

# %% [markdown]
# # BOM.MOVIE_GROSS

# %%
#loading data
bom_gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
bom_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %% [markdown]
# cleaning the data

# %%
# checking for duplicates
bom_gross.duplicated().sum()
# Out:
# 0

# %%
bom_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
bom_gross.isna().mean()*100
# Out:
# title              0.000000
# studio             0.147623
# domestic_gross     0.826690
# foreign_gross     39.858282
# year               0.000000
# dtype: float64

# %%
bom_gross.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
bom_gross['foreign_gross']
# Out:
# 0       652000000
# 1       691300000
# 2       664300000
# 3       535700000
# 4       513900000
#           ...
# 3382          NaN
# 3383          NaN
# 3384          NaN
# 3385          NaN
# 3386          NaN
# Name: foreign_gross, Length: 3387, dtype: object

# %%
#Remove commas and convert 'foreign_gross' to numeric
bom_gross['foreign_gross'] = pd.to_numeric(bom_gross['foreign_gross'].str.replace(',', ''), errors='coerce')

# %%
bom_gross.describe()
# Out:
#        domestic_gross  foreign_gross         year
# count    3.359000e+03   2.037000e+03  3387.000000
# mean     2.874585e+07   7.487281e+07  2013.958075
# std      6.698250e+07   1.374106e+08     2.478141
# min      1.000000e+02   6.000000e+02  2010.000000
# 25%      1.200000e+05   3.700000e+06  2012.000000
# 50%      1.400000e+06   1.870000e+07  2014.000000
# 75%      2.790000e+07   7.490000e+07  2016.000000
# max      9.367000e+08   9.605000e+08  2018.000000

# %%
# creating a variable named  numeric columns for KNN Imputer
numeric_columns = ['domestic_gross', 'foreign_gross']
imputer = KNNImputer(n_neighbors=5)
bom_gross[numeric_columns] = imputer.fit_transform(bom_gross[numeric_columns])

# %%
bom_gross.isna().sum()
# Out:
# title             0
# studio            5
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %%
bom_gross.dropna(subset=['studio'], inplace=True)

# %%
bom_gross.isna().sum()
# Out:
# title             0
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %%
bom_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3382 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3382 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3382 non-null   float64
#  3   foreign_gross   3382 non-null   float64
#  4   year            3382 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 158.5+ KB

# %%
# Creating a copy of the DataFrame
bom_gross_copy = bom_gross.copy()

# %% [markdown]
# # IM.DB DATABASE

# %% [markdown]
# #

# %%
#loading the data from the database
conn=sqlite3.connect("zippedData/im.db/im.db")
cur= conn.cursor()

# %%
# JOINING THE TABLES AND CONVERTING THE DATABASE FILE INTO DF
query = """ 
SELECT 
    mb.movie_id,
    mb.primary_title,
    mb.original_title,
    mb.genres,
    mb.start_year AS release_year,
    mb.runtime_minutes AS film_runtime,
    mr.averagerating AS imdb_average_rating,
    mr.numvotes AS imdb_number_of_votes,
    GROUP_CONCAT(DISTINCT(p.primary_name)) AS directors
FROM movie_basics AS mb
LEFT JOIN movie_ratings AS mr ON mb.movie_id = mr.movie_id
JOIN
directors AS d
USING (movie_id)
JOIN
persons AS p
USING (person_id)
GROUP BY mb.movie_id;
"""

imdb_df=pd.read_sql(query,conn)

# %% [markdown]
# DATA CLEANING

# %%
imdb_df.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#                  genres  release_year  film_runtime  imdb_average_rating  \
# 0    Action,Crime,Drama          2013         175.0                  7.0
# 1       Biography,Drama          2019         114.0                  7.2
# 2                 Drama          2018         122.0                  6.9
# 3          Comedy,Drama          2018           NaN                  6.1
# 4  Comedy,Drama,Fantasy          2017          80.0                  6.5
#
#    imdb_number_of_votes                     directors
# 0                  77.0           Harnam Singh Rawail
# 1                  43.0                     Mani Kaul
# 2                4517.0                  Orson Welles
# 3                  13.0          Hrishikesh Mukherjee
# 4                 119.0  Raoul Ruiz,Valeria Sarmiento

# %%
imdb_df.tail()
# Out:
#          movie_id                                primary_title  \
# 140411  tt9916538                          Kuambil Lagi Hatiku
# 140412  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 140413  tt9916706                              Dankyavar Danka
# 140414  tt9916730                                       6 Gunn
# 140415  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title       genres  \
# 140411                          Kuambil Lagi Hatiku        Drama
# 140412  Rodolpho Teóphilo - O Legado de um Pioneiro  Documentary
# 140413                              Dankyavar Danka       Comedy
# 140414                                       6 Gunn         None
# 140415               Chico Albuquerque - Revelações  Documentary
#
#         release_year  film_runtime  imdb_average_rating  imdb_number_of_votes  \
# 140411          2019         123.0                  NaN                   NaN
# 140412          2015           NaN                  NaN                   NaN
# 140413          2013           NaN                  NaN                   NaN
# 140414          2017         116.0                  NaN                   NaN
# 140415          2013           NaN                  NaN                   NaN
#
#                                    directors
# 140411                     Azhar Kinoi Lubis
# 140412   Angela Gurgel,Ana Célia de Oliveira
# 140413                         Kanchan Nayak
# 140414                          Kiran Gawade
# 140415  Vinicius Augusto Bozzo,Angela Gurgel

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140416 entries, 0 to 140415
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   movie_id              140416 non-null  object
#  1   primary_title         140416 non-null  object
#  2   original_title        140414 non-null  object
#  3   genres                137238 non-null  object
#  4   release_year          140416 non-null  int64
#  5   film_runtime          112019 non-null  float64
#  6   imdb_average_rating   73103 non-null   float64
#  7   imdb_number_of_votes  73103 non-null   float64
#  8   directors             140416 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 9.6+ MB

# %%
imdb_df.duplicated().sum()
# Out:
# 0

# %%
imdb_df.isna().mean()*100
# Out:
# movie_id                 0.000000
# primary_title            0.000000
# original_title           0.001424
# genres                   2.263275
# release_year             0.000000
# film_runtime            20.223479
# imdb_average_rating     47.938269
# imdb_number_of_votes    47.938269
# directors                0.000000
# dtype: float64

# %%
imdb_df.describe()
# Out:
#         release_year   film_runtime  imdb_average_rating  imdb_number_of_votes
# count  140416.000000  112019.000000         73103.000000          7.310300e+04
# mean     2014.610030      86.316741             6.329267          3.559320e+03
# std         2.732922     167.896407             1.473410          3.044756e+04
# min      2010.000000       1.000000             1.000000          5.000000e+00
# 25%      2012.000000      70.000000             5.500000          1.400000e+01
# 50%      2015.000000      87.000000             6.500000          5.000000e+01
# 75%      2017.000000      99.000000             7.300000          2.880000e+02
# max      2115.000000   51420.000000            10.000000          1.841066e+06

# %%
# Creating a copy of the DataFrame
imdb_df_copy = imdb_df.copy()

# %%
# handling missing values in numerical_columns
for i in ["film_runtime", "imdb_average_rating", "imdb_number_of_votes"]:
    imdb_df[i].fillna(imdb_df[i].median(), inplace=True)

# %%
imdb_df.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'genres', 'release_year',
#        'film_runtime', 'imdb_average_rating', 'imdb_number_of_votes',
#        'directors'],
#       dtype='object')

# %%
imdb_df.dropna(subset=['original_title', 'genres'], inplace=True)

# %%
imdb_df.isna().mean()*100
# Out:
# movie_id                0.0
# primary_title           0.0
# original_title          0.0
# genres                  0.0
# release_year            0.0
# film_runtime            0.0
# imdb_average_rating     0.0
# imdb_number_of_votes    0.0
# directors               0.0
# dtype: float64

# %%
imdb_df=imdb_df.copy()

# %%
imdb= imdb_df[['movie_id','primary_title','genres','directors']]

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137237 entries, 0 to 140415
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   movie_id       137237 non-null  object
#  1   primary_title  137237 non-null  object
#  2   genres         137237 non-null  object
#  3   directors      137237 non-null  object
# dtypes: object(4)
# memory usage: 5.2+ MB

# %%
# Creating a copy of the DataFrame
imdb = imdb.copy()

# %%
imdb=imdb.rename(columns={'directors': 'director'})
imdb= imdb.rename(columns={'genres': 'genre'})
imdb = imdb.rename(columns={'primary_title': 'title'})

# %% [markdown]
# # MERGING THE FIRST 2 DATASET

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137237 entries, 0 to 140415
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   movie_id  137237 non-null  object
#  1   title     137237 non-null  object
#  2   genre     137237 non-null  object
#  3   director  137237 non-null  object
# dtypes: object(4)
# memory usage: 5.2+ MB

# %%
bom_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3382 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3382 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3382 non-null   float64
#  3   foreign_gross   3382 non-null   float64
#  4   year            3382 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 158.5+ KB

# %%
movie_merged=pd.merge(imdb,bom_gross,on='title',how='inner')

# %%
movie_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3294 entries, 0 to 3293
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        3294 non-null   object
#  1   title           3294 non-null   object
#  2   genre           3294 non-null   object
#  3   director        3294 non-null   object
#  4   studio          3294 non-null   object
#  5   domestic_gross  3294 non-null   float64
#  6   foreign_gross   3294 non-null   float64
#  7   year            3294 non-null   int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 231.6+ KB

# %%
movie_merged.isna().mean()*100
# Out:
# movie_id          0.0
# title             0.0
# genre             0.0
# director          0.0
# studio            0.0
# domestic_gross    0.0
# foreign_gross     0.0
# year              0.0
# dtype: float64

# %%
movie_merged.duplicated().sum()
# Out:
# 0

# %%
movie_merged=movie_merged.copy()

# %% [markdown]
# # MOVIE_INFO

# %%
# loading data for movie information
movie_info = pd.read_csv('zippedData/rt.movie_info.tsv.gz', delimiter='\t')
movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
movie_info.duplicated().sum()
# Out:
# 0

# %%
movie_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
movie_info.isna().mean()*100
# Out:
# id               0.000000
# synopsis         3.974359
# rating           0.192308
# genre            0.512821
# director        12.756410
# writer          28.782051
# theater_date    23.012821
# dvd_date        23.012821
# currency        78.205128
# box_office      78.205128
# runtime          1.923077
# studio          68.333333
# dtype: float64

# %%
# dropping columns
movie_info.drop(columns=['currency', 'box_office','studio'],inplace=True)

# %%
categorical_columns = movie_info.select_dtypes(include="object").columns

for i in categorical_columns:
    movie_info[i].fillna('unknown', inplace=True)

# %%
# selecting useful columns
new_movie = movie_info[['id', 'genre', 'director', 'writer','rating']]
new_movie.head()
# Out:
#    id                                genre          director  \
# 0   1  Action and Adventure|Classics|Drama  William Friedkin
# 1   3    Drama|Science Fiction and Fantasy  David Cronenberg
# 2   5    Drama|Musical and Performing Arts    Allison Anders
# 3   6           Drama|Mystery and Suspense    Barry Levinson
# 4   7                        Drama|Romance    Rodney Bennett
#
#                             writer rating
# 0                   Ernest Tidyman      R
# 1     David Cronenberg|Don DeLillo      R
# 2                   Allison Anders      R
# 3  Paul Attanasio|Michael Crichton      R
# 4                     Giles Cooper     NR

# %%
new_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        1560 non-null   int64
#  1   genre     1560 non-null   object
#  2   director  1560 non-null   object
#  3   writer    1560 non-null   object
#  4   rating    1560 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 61.1+ KB

# %%
new_movie.isna().sum()
# Out:
# id          0
# genre       0
# director    0
# writer      0
# rating      0
# dtype: int64

# %%
new_movie=new_movie.copy()

# %%
new_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        1560 non-null   int64
#  1   genre     1560 non-null   object
#  2   director  1560 non-null   object
#  3   writer    1560 non-null   object
#  4   rating    1560 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 61.1+ KB

# %%
movie_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3294 entries, 0 to 3293
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        3294 non-null   object
#  1   title           3294 non-null   object
#  2   genre           3294 non-null   object
#  3   director        3294 non-null   object
#  4   studio          3294 non-null   object
#  5   domestic_gross  3294 non-null   float64
#  6   foreign_gross   3294 non-null   float64
#  7   year            3294 non-null   int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 231.6+ KB

# %% [markdown]
# # 2nd MERGING

# %%
movie_merged2=pd.merge(movie_merged,new_movie,on=['director','genre'],how='inner')
movie_merged2.head()
# Out:
#     movie_id                title   genre              director studio  \
# 0  tt5647250          On the Road   Drama  Michael Winterbottom    IFC
# 1  tt1836987              Trishna   Drama  Michael Winterbottom    IFC
# 2  tt0427152  Dinner for Schmucks  Comedy             Jay Roach   P/DW
# 3  tt0427152  Dinner for Schmucks  Comedy             Jay Roach   P/DW
# 4  tt1790886         The Campaign  Comedy             Jay Roach     WB
#
#    domestic_gross  foreign_gross  year    id                     writer rating
# 0        744000.0      8000000.0  2012  1959                Paul Powell      R
# 1        240000.0      3160200.0  2012  1959                Paul Powell      R
# 2      73000000.0     13800000.0  2010   883  Jim Herzfeld|John Hamburg  PG-13
# 3      73000000.0     13800000.0  2010  1446  John Hamburg|Jim Herzfeld  PG-13
# 4      86900000.0     18000000.0  2012   883  Jim Herzfeld|John Hamburg  PG-13

# %%
movie_merged2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        20 non-null     object
#  1   title           20 non-null     object
#  2   genre           20 non-null     object
#  3   director        20 non-null     object
#  4   studio          20 non-null     object
#  5   domestic_gross  20 non-null     float64
#  6   foreign_gross   20 non-null     float64
#  7   year            20 non-null     int64
#  8   id              20 non-null     int64
#  9   writer          20 non-null     object
#  10  rating          20 non-null     object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 1.9+ KB

# %%
movie_merged2.isna().sum()
# Out:
# movie_id          0
# title             0
# genre             0
# director          0
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# id                0
# writer            0
# rating            0
# dtype: int64

# %%
movie_merged2.duplicated().sum()
# Out:
# 0

# %%
movie_merged2=movie_merged2.copy()

# %% [markdown]
# # MOVIE_BUDGET

# %%
# loading data for movie budget
movie_budget = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
movie_budget.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
movie_budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
movie_budget=movie_budget.rename(columns={' release_date': 'year'})
movie_budget= movie_budget.rename(columns={'worldwide_gross':'foreign_gross '})

# %%
movie_budget.isna().sum()
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# foreign_gross        0
# dtype: int64

# %%
movie_budget.duplicated().sum()
# Out:
# 0

# %%
movie_merged2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        20 non-null     object
#  1   title           20 non-null     object
#  2   genre           20 non-null     object
#  3   director        20 non-null     object
#  4   studio          20 non-null     object
#  5   domestic_gross  20 non-null     float64
#  6   foreign_gross   20 non-null     float64
#  7   year            20 non-null     int64
#  8   id              20 non-null     int64
#  9   writer          20 non-null     object
#  10  rating          20 non-null     object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 1.9+ KB

# %%
movie_merged3=pd.merge(movie_merged,new_movie,on=['genre','director'],how='inner')
movie_merged3.head(20)
# Out:
#      movie_id                             title        genre  \
# 0   tt5647250                       On the Road        Drama
# 1   tt1836987                           Trishna        Drama
# 2   tt0427152               Dinner for Schmucks       Comedy
# 3   tt0427152               Dinner for Schmucks       Comedy
# 4   tt1790886                      The Campaign       Comedy
# 5   tt1790886                      The Campaign       Comedy
# 6   tt1454029                          The Help        Drama
# 7   tt1622979               Final Destination 5       Horror
# 8   tt1650453                            I Wish        Drama
# 9   tt2004420                         Neighbors       Comedy
# 10  tt4438848      Neighbors 2: Sorority Rising       Comedy
# 11  tt2479800                         Palo Alto        Drama
# 12  tt2637276                             Ted 2       Comedy
# 13  tt2883434                    Black or White        Drama
# 14  tt3233418                       Spare Parts        Drama
# 15  tt3892172                    Leave No Trace        Drama
# 16  tt4653272    Buena Vista Social Club: Adios  Documentary
# 17  tt4667094             Fifty Shades of Black       Comedy
# 18  tt6257174  The Miseducation of Cameron Post        Drama
# 19  tt8267604                         Capernaum        Drama
#
#                 director   studio  domestic_gross  foreign_gross  year    id  \
# 0   Michael Winterbottom      IFC        744000.0      8000000.0  2012  1959
# 1   Michael Winterbottom      IFC        240000.0      3160200.0  2012  1959
# 2              Jay Roach     P/DW      73000000.0     13800000.0  2010   883
# 3              Jay Roach     P/DW      73000000.0     13800000.0  2010  1446
# 4              Jay Roach       WB      86900000.0     18000000.0  2012   883
# 5              Jay Roach       WB      86900000.0     18000000.0  2012  1446
# 6            Tate Taylor       BV     169700000.0     46900000.0  2011  1321
# 7           Steven Quale  WB (NL)      42600000.0    115300000.0  2011  1011
# 8       Hirokazu Koreeda    Magn.        146000.0      1400000.0  2012  1112
# 9       Nicholas Stoller     Uni.     150200000.0    120500000.0  2014   760
# 10      Nicholas Stoller     Uni.      55500000.0     52600000.0  2016   760
# 11           Gia Coppola    Trib.        768000.0     47560000.0  2014  1084
# 12       Seth MacFarlane     Uni.      81500000.0    135200000.0  2015   714
# 13           Mike Binder    Rela.      21600000.0     17197400.0  2015  1362
# 14         Sean McNamara      LGF       3600000.0      5040000.0  2015   876
# 15          Debra Granik      BST       6000000.0      6940119.8  2018   271
# 16           Lucy Walker       BG        123000.0       578000.0  2017  1839
# 17        Michael Tiddes      ORF      11700000.0     10500000.0  2016   355
# 18       Desiree Akhavan       FR        905000.0     66496600.0  2018  1374
# 19         Nadine Labaki      SPC       1700000.0     10480000.0  2018  1910
#
#                                                writer rating
# 0                                         Paul Powell      R
# 1                                         Paul Powell      R
# 2                           Jim Herzfeld|John Hamburg  PG-13
# 3                           John Hamburg|Jim Herzfeld  PG-13
# 4                           Jim Herzfeld|John Hamburg  PG-13
# 5                           John Hamburg|Jim Herzfeld  PG-13
# 6   Tate Taylor|Jez Butterworth|John-Henry Butterw...  PG-13
# 7                                      Eric Heisserer      R
# 8                                    Hirokazu Koreeda     PG
# 9                                             unknown      R
# 10                                            unknown      R
# 11                                        Gia Coppola      R
# 12         Seth MacFarlane|Alec Sulkin|Wellesley Wild      R
# 13                                        Mike Binder  PG-13
# 14                  David Aaron Cohen|Elissa Matsueda     PG
# 15                        Debra Granik|Richard Lieske      R
# 16                                            unknown     PG
# 17                                      Marlon Wayans      R
# 18                  Desiree Akhavan|Cecilia Frugiuele     NR
# 19     Nadine Labaki|Jihad Hojeily|Michelle Kesrouani      R

# %%
movie_merged3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        20 non-null     object
#  1   title           20 non-null     object
#  2   genre           20 non-null     object
#  3   director        20 non-null     object
#  4   studio          20 non-null     object
#  5   domestic_gross  20 non-null     float64
#  6   foreign_gross   20 non-null     float64
#  7   year            20 non-null     int64
#  8   id              20 non-null     int64
#  9   writer          20 non-null     object
#  10  rating          20 non-null     object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 1.9+ KB

# %%
m
